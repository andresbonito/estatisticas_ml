# %% [markdown]
# #Criação do Dataset

# %%
import pandas as pd
import numpy as np
import statistics
import math
import random

# %%
# dados = [150, 151, 152, 152, 153, 154, 155, 155, 155]
# dados = [150, 150, 151, 152, 152, 153, 154, 155, 156, 157, 157, 157, 159, 159, 160, 161, 161, 162, 163, 164, 166, 166, 167, 168, 169, 170, 170, 171]
dados = [random.randint(160, 190) for _ in range(100)]

# %%
intervalos = [(145, 150), (150, 155), (155, 160), (160, 165), (165, 170), (170, 175), (175, 180), (180, 185), (185, 190), (190, 195), (195, 200)]

# %%
def encontrar_intervalo(valor):
    for intervalo in intervalos:
        if intervalo[0] <= valor < intervalo[1]:
            return intervalo
    return None

# %%
intervalos_encontrados = [encontrar_intervalo(valor) for valor in dados]

# %%
dataset = pd.DataFrame({'Valor': dados, 'Intervalo': intervalos_encontrados})
dataset
# Out:
#     Valor   Intervalo
# 0     188  (185, 190)
# 1     173  (170, 175)
# 2     171  (170, 175)
# 3     175  (175, 180)
# 4     175  (175, 180)
# ..    ...         ...
# 95    179  (175, 180)
# 96    185  (185, 190)
# 97    173  (170, 175)
# 98    189  (185, 190)
# 99    160  (160, 165)
#
# [100 rows x 2 columns]

# %%
new_dataset = dataset.groupby('Intervalo').size().reset_index(name='Quantidade')
new_dataset
# Out:
#     Intervalo  Quantidade
# 0  (160, 165)          13
# 1  (165, 170)          13
# 2  (170, 175)          17
# 3  (175, 180)          19
# 4  (180, 185)          16
# 5  (185, 190)          18
# 6  (190, 195)           4

# %%
pontos_medios = []

# %%
for i in new_dataset['Intervalo']:
  Li = i[1]
  li = i[0]

  pontos_medios.append((Li + li) / 2)

pontos_medios
# Out:
# [162.5, 167.5, 172.5, 177.5, 182.5, 187.5, 192.5]

# %%
new_dataset['pontos_medios'] = pontos_medios
new_dataset
# Out:
#     Intervalo  Quantidade  pontos_medios
# 0  (160, 165)          13          162.5
# 1  (165, 170)          13          167.5
# 2  (170, 175)          17          172.5
# 3  (175, 180)          19          177.5
# 4  (180, 185)          16          182.5
# 5  (185, 190)          18          187.5
# 6  (190, 195)           4          192.5

# %%
new_dataset['fi.xi'] = new_dataset['Quantidade'] * new_dataset['pontos_medios']
new_dataset
# Out:
#     Intervalo  Quantidade  pontos_medios   fi.xi
# 0  (160, 165)          13          162.5  2112.5
# 1  (165, 170)          13          167.5  2177.5
# 2  (170, 175)          17          172.5  2932.5
# 3  (175, 180)          19          177.5  3372.5
# 4  (180, 185)          16          182.5  2920.0
# 5  (185, 190)          18          187.5  3375.0
# 6  (190, 195)           4          192.5   770.0

# %%
Fi = []

for q, quantidade in enumerate(new_dataset['Quantidade']):
  if len(Fi) == 0:
    Fi.append(quantidade)
  else:
    valor_anterior = Fi[q - 1 if len(Fi) > 0 else 0]
    Fi.append(quantidade + valor_anterior)

Fi
# Out:
# [13, 26, 43, 62, 78, 96, 100]

# %%
new_dataset['Fi'] = Fi
new_dataset
# Out:
#     Intervalo  Quantidade  pontos_medios   fi.xi   Fi
# 0  (160, 165)          13          162.5  2112.5   13
# 1  (165, 170)          13          167.5  2177.5   26
# 2  (170, 175)          17          172.5  2932.5   43
# 3  (175, 180)          19          177.5  3372.5   62
# 4  (180, 185)          16          182.5  2920.0   78
# 5  (185, 190)          18          187.5  3375.0   96
# 6  (190, 195)           4          192.5   770.0  100

# %% [markdown]
# #Media

# %%
def media(dataset):
  t_fi_xi = dataset['fi.xi'].sum()
  t_quantidade = dataset['Quantidade'].sum()

  return t_fi_xi / t_quantidade

# %%
media_aritmetica = media(new_dataset)
media_aritmetica
# Out:
# 176.6

# %% [markdown]
# #Moda

# %%
moda = statistics.mode(dados)
moda
# Out:
# 184

# %% [markdown]
# #Mediana

# %%
mediana = statistics.median(dados)
mediana
# Out:
# 176.0

# %%
#maneira de identificar a qual intervalo a mediana pertence
for i, intervalo in enumerate(new_dataset['Intervalo']):
  if mediana > intervalo[1]:
    continue
  elif mediana < intervalo[1] and mediana >= intervalo[0]:
    intervalo_m = i

intervalo_m
# Out:
# 3

# %%
l = new_dataset['Intervalo'][intervalo_m][0]
soma_fi = new_dataset['Quantidade'].sum() / 2
h = new_dataset['Intervalo'][intervalo_m][1] - new_dataset['Intervalo'][intervalo_m][0]
fi = new_dataset['Quantidade'][intervalo_m]
f_ant = new_dataset['Fi'][intervalo_m - 1]

# %%
md = l + (((soma_fi - f_ant) * h) / fi)
md
# Out:
# 176.8421052631579

# %% [markdown]
# #Distribuição de Frequência

# %%
#amplitude de um intervalo
for h in new_dataset['Intervalo']:
  hi = h[1] - h[0]
  print(hi)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
#amplitude total da distribuição
amplitude_t = max(dados) - min(dados)
amplitude_t
# Out:
# 30

# %%
#amplitude amostral
amplitude_a = max(dados) - min(dados)
amplitude_a
# Out:
# 30

# %%
#determinar o numero de classes
i = 1 + 3.3 * math.log((soma_fi * 2), 10)
i
# Out:
# 7.6

# %%
#determinar amplitude do intervalo de classe
hc = amplitude_a / i
round(hc, 0)
# Out:
# 4.0

# %% [markdown]
# #Media Geometrica

# %%
n = len(dados)
xn = 1
log_xn = sum(math.log(numero) for numero in dados)

g = math.exp(log_xn / n)
g
# Out:
# 175.88559259255018

# %% [markdown]
# #Media Harmônica

# %%
xn_2 = 0
for numero in dados:
  xn_2 += 1/numero

mh = n / xn_2
mh
# Out:
# 175.65969530487814

# %% [markdown]
# #Média Quadratica

# %%
xn_3 = 0
for numero in dados:
  xn_3 += numero ** 2

qm = math.sqrt(xn_3/n)
qm
# Out:
# 176.33261184477476

# %% [markdown]
# #Variância

# %%
x_barra = sum(dados) / len(dados)
x_barra
# Out:
# 176.11

# %% [markdown]
# #Desvio Padrão

# %%
desvio = []
for numero in dados:
  desvio.append((numero - x_barra) ** 2)
  sigma = math.sqrt(sum(desvio) / len(dados))

sigma
# Out:
# 8.857646414257006

# %% [markdown]
# #Coeficiente de Variação

# %%
coeficiente_variacao = (sigma / x_barra) * 100
coeficiente_variacao
# Out:
# 5.029610138127878

# %% [markdown]
# #Desvio Padrão em Dados Agrupados

# %%
new_dataset['x1.2'] = new_dataset['pontos_medios'] ** 2
new_dataset
# Out:
#     Intervalo  Quantidade  pontos_medios   fi.xi   Fi      x1.2
# 0  (160, 165)          13          162.5  2112.5   13  26406.25
# 1  (165, 170)          13          167.5  2177.5   26  28056.25
# 2  (170, 175)          17          172.5  2932.5   43  29756.25
# 3  (175, 180)          19          177.5  3372.5   62  31506.25
# 4  (180, 185)          16          182.5  2920.0   78  33306.25
# 5  (185, 190)          18          187.5  3375.0   96  35156.25
# 6  (190, 195)           4          192.5   770.0  100  37056.25

# %%
new_dataset['fi.x1.2'] = new_dataset['fi.xi'] ** 2
new_dataset
# Out:
#     Intervalo  Quantidade  pontos_medios   fi.xi   Fi      x1.2      fi.x1.2
# 0  (160, 165)          13          162.5  2112.5   13  26406.25   4462656.25
# 1  (165, 170)          13          167.5  2177.5   26  28056.25   4741506.25
# 2  (170, 175)          17          172.5  2932.5   43  29756.25   8599556.25
# 3  (175, 180)          19          177.5  3372.5   62  31506.25  11373756.25
# 4  (180, 185)          16          182.5  2920.0   78  33306.25   8526400.00
# 5  (185, 190)          18          187.5  3375.0   96  35156.25  11390625.00
# 6  (190, 195)           4          192.5   770.0  100  37056.25    592900.00

# %%
x1 = sum(new_dataset['fi.x1.2']) / sum(new_dataset['Quantidade'])
x2 = (sum(new_dataset['fi.xi']) / sum(new_dataset['Quantidade'])) ** 2
x3 = x1 - x2
dp = math.sqrt(x3)
dp
# Out:
# 682.4122214614858
